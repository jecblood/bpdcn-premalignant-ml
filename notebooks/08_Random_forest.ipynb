# %%
import os
os.chdir('/Users/jeffreybloodworth/Desktop/git-repos/scRNAseq-ExplainableML')
os.getcwd()
# Out:
# '/Users/jeffreybloodworth/Desktop/git-repos/scRNAseq-ExplainableML'

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = pd.read_csv(
    "data/processed/ml_matrix_top2000.csv.gz",
    index_col=0
)

meta = pd.read_csv(
    "data/processed/pdc_metadata.csv"
)

print(X.shape)
print(meta.shape)
# Out:
# (4846, 2000)
# (14430, 58)

# %%
meta["is_malignant"].value_counts()
# Out:
# is_malignant
# Malignant       13732
# Premalignant      495
# Healthy           203
# Name: count, dtype: int64

# %%
y = pdc_meta["is_malignant"].map({
    "Premalignant": 0,
    "Malignant": 1
})

y.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 y = pdc_meta["is_malignant"].map({
#       2     "Premalignant": 0,
#       3     "Malignant": 1
#       4 })
#
# NameError: name 'pdc_meta' is not defined

# %%
meta.columns[:5]
# Out:
# Index(['cell', 'orig.ident', 'orig.ident2', 'nCount_RNA', 'nFeature_RNA'], dtype='str')

# %%
meta.shape
# Out:
# (14430, 58)

# %%
meta.columns[0]
# Out:
# 'cell'

# %%
barcode_col = meta.columns[0]

meta_rf = meta[
    meta[barcode_col].isin(X.index)
].copy()

print(meta_rf.shape)
# Out:
# (4846, 58)

# %%
meta_rf = (
    meta_rf
    .set_index(barcode_col)
    .loc[X.index]
    .reset_index()
)

# %%
print(meta_rf.columns.tolist())
print(meta_rf.head())
# Out:
# ['index', 'orig.ident', 'orig.ident2', 'nCount_RNA', 'nFeature_RNA', 'replicate', 'tech', 'CellType', 'project.umap.x', 'project.umap.y', 'MALAT1.chr11:65270399:G/A', 'NFIC.chr19:3462800:G/A', 'NOTCH1.chr9:139389423:C/T', 'TET2.Q1537*', 'bm_involvement', 'is_malignant', 'sample', 'TET2.N281fs*', 'TET2.V1395fs*', 'ZRSR2.Y175*', 'ASXL1.L697fs*', 'FAM98C.chr19:38899400:G/A', 'SETX.chr9:135136947:G/A', 'SMARCC1.chr3:47627735:G/A', 'TET2.Q960*', 'ASXL1.R693*', 'TET2.Q876*', 'TET2.S794*', 'ZRSR2.R126*', 'CUX1.L911fs*', 'TET2.E1437fs*', 'TET2.Q1547*', 'ETV6.R369W', 'EZH2.P132L', 'IDH2.R140Q', 'UMAP_1', 'UMAP_2', 'S.Score', 'G2M.Score', 'Phase', 'ASXL1.V807fs*', 'TET2.R1516*', 'U2AF1.S34F', 'ACAP2.L97M', 'ASXL1.G642fs', 'CWF19L2.K221R', 'DOLPP1.R227S', 'HNRNPUL1.F559F', 'MAP4K5.P667S', 'RAB9A.3pUTR', 'TET2.H1380Y', 'TET2.Q1034*', 'TET2.R1216*', 'TET2.S792*', 'MTAP.rearr', 'PRKDC.chr8:48713410:C/T', 'RPS24.chr10:79795273:T/C', 'SMARCD1.chr12:50490729:C/T']
# ...

# %%
all(
    meta_rf["index"].values
    ==
    X.index.values
)
# Out:
# True

# %%
print(X.shape)
print(meta_rf.shape)
# Out:
# (4846, 2000)
# (4846, 58)

# %%
meta_rf["is_malignant"].value_counts()
# Out:
# is_malignant
# Malignant       4405
# Premalignant     441
# Name: count, dtype: int64

# %%
y = meta_rf["is_malignant"].map({
    "Premalignant": 0,
    "Malignant": 1
})

print(len(y))
print(X.shape)
# Out:
# 4846
# (4846, 2000)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    stratify=y,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=500,
    random_state=42,
    class_weight="balanced",
    n_jobs=-1
)

# %%
rf.fit(
    X_train,
    y_train
)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=500, n_jobs=-1,
#                        random_state=42)

# %%
pred = rf.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        y_test,
        pred
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        88
#            1       1.00      1.00      1.00       882
#
#     accuracy                           1.00       970
#    macro avg       0.99      1.00      1.00       970
# weighted avg       1.00      1.00      1.00       970

# %%
importance = pd.DataFrame({
    "gene": X.columns,
    "importance": rf.feature_importances_
})

importance = importance.sort_values(
    "importance",
    ascending=False
)

importance.head(20)
# Out:
#           gene  importance
# 1555    ALKBH7    0.034510
# 159       HES6    0.029758
# 238    ALOX5AP    0.027202
# 1198     SHTN1    0.026159
# 1546   SIGLEC6    0.023957
# 190     PDLIM1    0.021746
# 1697     SIRPG    0.019552
# 934      RAMP1    0.018288
# 1777  SLC25A11    0.018233
# 1962   SINHCAF    0.018077
# 1353   SLC15A4    0.017923
# 1181     SKAP2    0.017025
# 1799   SLC38A1    0.016923
# 1997      SHQ1    0.015404
# 848      PLCG2    0.015155
# 980       SLBP    0.014544
# 186      SIVA1    0.014391
# 196      RPL31    0.013812
# 40       IGLL1    0.013755
# 146    SLC25A5    0.013326

# %%
importance.to_csv(
    "results/rf_feature_importance.csv",
    index=False
)

# %%
from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay
)

import matplotlib.pyplot as plt

cm = confusion_matrix(
    y_test,
    pred
)

print(cm)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[
        "Premalignant",
        "Malignant"
    ]
)

disp.plot(
    cmap="Blues",
    values_format="d"
)

plt.title(
    "Random Forest Confusion Matrix"
)

plt.tight_layout()

plt.savefig(
    "figures/rf_confusion_matrix.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# [[ 88   0]
#  [  1 881]]

# %%
importance = pd.DataFrame({
    "gene": X.columns,
    "importance": rf.feature_importances_
})

importance = importance.sort_values(
    "importance",
    ascending=False
)

# %%
top20 = importance.head(20)

# %%
import matplotlib.pyplot as plt

plt.figure(
    figsize=(8, 6)
)

plt.barh(
    top20["gene"],
    top20["importance"]
)

plt.gca().invert_yaxis()

plt.xlabel(
    "Feature Importance"
)

plt.ylabel(
    "Gene"
)

plt.title(
    "Top 20 Random Forest Features"
)

plt.tight_layout()

plt.savefig(
    "figures/rf_top20_genes.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
importance.to_csv(
    "results/rf_feature_importance.csv",
    index=False
)

# %%
importance.head(20)
# Out:
#           gene  importance
# 1555    ALKBH7    0.034510
# 159       HES6    0.029758
# 238    ALOX5AP    0.027202
# 1198     SHTN1    0.026159
# 1546   SIGLEC6    0.023957
# 190     PDLIM1    0.021746
# 1697     SIRPG    0.019552
# 934      RAMP1    0.018288
# 1777  SLC25A11    0.018233
# 1962   SINHCAF    0.018077
# 1353   SLC15A4    0.017923
# 1181     SKAP2    0.017025
# 1799   SLC38A1    0.016923
# 1997      SHQ1    0.015404
# 848      PLCG2    0.015155
# 980       SLBP    0.014544
# 186      SIVA1    0.014391
# 196      RPL31    0.013812
# 40       IGLL1    0.013755
# 146    SLC25A5    0.013326
